# %%
import string
from pickle import dump
from numpy import array
from pickle import load
from unicodedata import normalize
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.models import Model
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()

	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# split on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'kan-eng.tsv'
doc = load_doc(filename)
# split into english-kannada pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-kannada36.pkl')
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))


# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-kannada36.pkl')

# reduce dataset size
n_sentences = 36000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:34000], dataset[34000:]
# save
save_clean_data(dataset, 'english-kannada-both36.pkl')
save_clean_data(train, 'english-kannada-train36.pkl')
save_clean_data(test, 'english-kannada-test36.pkl')
# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# load datasets
dataset = load_clean_sentences('english-kannada-both36.pkl')
train = load_clean_sentences('english-kannada-train36.pkl')
test = load_clean_sentences('english-kannada-test36.pkl')
# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer
# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare kannada tokenizer
kan_tokenizer = create_tokenizer(dataset[:, 1])
kan_vocab_size = len(kan_tokenizer.word_index) + 1
kan_length = max_length(dataset[:, 1])
print('Kannada Vocabulary Size: %d' % kan_vocab_size)
print('Kannada Max Length: %d' % (kan_length))
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X
# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y
# prepare training data
trainX = encode_sequences(kan_tokenizer, kan_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(kan_tokenizer, kan_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)
# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# define model
model = define_model(kan_vocab_size, eng_vocab_size, kan_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename='model32k.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=1000, batch_size=128, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# Saved: english-kannada36.pkl
# [go.] => [ಹೋಗಿ.]
# [run!] => [ಓಡು!]
# [run!] => [ಓಡು!]
# [run!] => [ಓಡು!]
# [run!] => [ಓಡು!]
# [who?] => [ಯಾರು?]
# [wow!] => [ಅದ್ಭುತ!]
# [fire!] => [ಬೆಂಕಿ!]
# [fire!] => [ಬೆಂಕಿ!]
# [help!] => [ಸಹಾಯ!]
# [help!] => [ಸಹಾಯ!]
# [jump!] => [ನೆಗೆಯುವುದನ್ನು!]
# [jump!] => [ನೆಗೆಯುವುದನ್ನು!]
# [jump.] => [ನೆಗೆಯುವುದನ್ನು.]
# [jump.] => [ನೆಗೆಯುವುದನ್ನು.]
# [stop!] => [ನಿಲ್ಲಿಸು!]
# [stop!] => [ನಿಲ್ಲಿಸು!]
# [wait!] => [ನಿರೀಕ್ಷಿಸಿ!]
# [wait!] => [ನಿರೀಕ್ಷಿಸಿ!]
# [hello!] => [ಹಲೋ!]
# [hurry!] => [ಯದ್ವಾತದ್ವಾ!]
# [hurry!] => [ಯದ್ವಾತದ್ವಾ!]
# [hurry!] => [ಯದ್ವಾತದ್ವಾ!]
# [i won!] => [ನಾನು ಗೆದ್ದೆ!]
# [i won!] => [ನಾನು ಗೆದ್ದೆ!]
# [get up.] => [ಎದ್ದೇಳು.]
# [got it!] => [ಅರ್ಥವಾಯಿತು!]
# [got it?] => [ಅರ್ಥವಾಯಿತು?]
# [got it?] => [ಅರ್ಥವಾಯಿತು?]
# [got it?] => [ಅರ್ಥವಾಯಿತು?]
# [got it?] => [ಅರ್ಥವಾಯಿತು?]
# [he ran.] => [ಅವನು ಓಡಿದ.]
# [he ran.] => [ಅವನು ಓಡಿದ.]
# [he ran.] => [ಅವನು ಓಡಿದ.]
# [he ran.] => [ಅವನು ಓಡಿದ.]
# [i fell.] => [ನಾನು ಬಿದ್ದೆ.]
# [i fell.] => [ನಾನು ಬಿದ್ದೆ.]
# [i fell.] => [ನಾನು ಬಿದ್ದೆ.]
# [i fell.] => [ನಾನು ಬಿದ್ದೆ.]
# [i know.] => [ನನಗೆ ಗೊತ್ತು.]
# [i know.] => [ನನಗೆ ಗೊತ್ತು.]
# [i know.] => [ನನಗೆ ಗೊತ್ತು.]
# [i lost.] => [ನಾನು ಕಳೆದುಕೊಂಡೆ.]
# [i lost.] => [ನಾನು ಕಳೆದುಕೊಂಡೆ.]
# [i work.] => [ನಾನು ಕೆಲಸದಲ್ಲಿರುವೆ.]
# [i work.] => [ನಾನು ಕೆಲಸದಲ್ಲಿರುವೆ.]
# [i'm ok.] => [ನಾನು ಸರಿ.]
# [listen.] => [ಕೇಳು.]
# [listen.] => [ಕೇಳು.]
# [really?] => [ನಿಜವಾಗಿಯೂ?]
# [really?] => [ನಿಜವಾಗಿಯೂ?]
# [really?] => [ನಿಜವಾಗಿಯೂ?]
# [thanks.] => [ಧನ್ಯವಾದಗಳು.]
# [we won.] => [ನಾವು ಗೆದ್ದಿದ್ದೇವೆ.]
# [we won.] => [ನಾವು ಗೆದ್ದಿದ್ದೇವೆ.]
# [why me?] => [ನಾನು ಯಾಕೆ?]
# [why me?] => [ನಾನು ಯಾಕೆ?]
# [ask sreenivas.] => [ಶ್ರೀನಿವಾಸ್ ಕೇಳಿ.]
# [ask sreenivas.] => [ಶ್ರೀನಿವಾಸ್ ಕೇಳಿ.]
# [call me.] => [ಕರೆ ಮಾಡು.]
# [call me.] => [ಕರೆ ಮಾಡು.]
# [call me.] => [ಕರೆ ಮಾಡು.]
# [call me.] => [ಕರೆ ಮಾಡು.]
# [call us.] => [ನಮ್ಮನ್ನು ಕರೆ ಮಾಡಿ.]
# [call us.] => [ನಮ್ಮನ್ನು ಕರೆ ಮಾಡಿ.]
# [come in.] => [ಒಳಗೆ ಬನ್ನಿ.]
# [fold it.] => [ಅದನ್ನು ಪದರ ಮಾಡಿ.]
# [fold it.] => [ಅದನ್ನು ಪದರ ಮಾಡಿ.]
# [get sreenivas.] => [ಶ್ರೀನಿವಾಸ್ ಪಡೆಯಿರಿ.]
# [get sreenivas.] => [ಶ್ರೀನಿವಾಸ್ ಪಡೆಯಿರಿ.]
# [get sreenivas.] => [ಶ್ರೀನಿವಾಸ್ ಪಡೆಯಿರಿ.]
# [get out.] => [ತೊಲಗು.]
# [get out.] => [ತೊಲಗು.]
# [go home.] => [ಮನೆಗೆ ಹೋಗು.]
# [he came.] => [ಅವನು ಬಂದ.]
# [he came.] => [ಅವನು ಬಂದ.]
# [he runs.] => [ಅವನು ಓಡುತ್ತಾನೆ.]
# [he runs.] => [ಅವನು ಓಡುತ್ತಾನೆ.]
# [he runs.] => [ಅವನು ಓಡುತ್ತಾನೆ.]
# [he runs.] => [ಅವನು ಓಡುತ್ತಾನೆ.]
# [help me!] => [ನನಗೆ ಸಹಾಯ ಮಾಡಿ!]
# [help me!] => [ನನಗೆ ಸಹಾಯ ಮಾಡಿ!]
# [help me!] => [ನನಗೆ ಸಹಾಯ ಮಾಡಿ!]
# [help me.] => [ನನಗೆ ಸಹಾಯ ಮಾಡಿ.]
# [help me.] => [ನನಗೆ ಸಹಾಯ ಮಾಡಿ.]
# [help us.] => [ನಮಗೆ ಸಹಾಯ ಮಾಡಿ.]
# [help us.] => [ನಮಗೆ ಸಹಾಯ ಮಾಡಿ.]
# [help us.] => [ನಮಗೆ ಸಹಾಯ ಮಾಡಿ.]
# [i'm sreenivas.] => [ನಾನು ಶ್ರೀನಿವಾಸ್.]
# [i'm kshamitha] => [ನಾನು ಕ್ಷಾಮಿತಾ]
# [i'm medhini] => [ನಾನು ಮೇಧಿನಿ]
# [i'm fat.] => [ನಾನು ದಪ್ಪಗಿದ್ದೇನೆ.]
# [i'm fat.] => [ನಾನು ದಪ್ಪಗಿದ್ದೇನೆ.]
# [i'm ill.] => [ನನಗೆ ಮೈ ಹುಷಾರಿಲ್ಲ.]
# [it's ok.] => [ಪರವಾಗಿಲ್ಲ.]
# [it's me!] => [ಇದು ನಾನು!]
# [it's me.] => [ಇದು ನಾನು.]
# ["me, too."] => [ನಾನೂ ಕೂಡ.]
# ["me, too."] => [ನಾನೂ ಕೂಡ.]
# [open up.] => [ತೆರೆಯಿರಿ.]
# Saved: english-kannada-both36.pkl
# Saved: english-kannada-train36.pkl
# Saved: english-kannada-test36.pkl
# English Vocabulary Size: 5047
# English Max Length: 11
# Kannada Vocabulary Size: 13244
# Kannada Max Length: 11
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 11, 256)           3390464
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_3 (RepeatVecto (None, 11, 256)           0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 11, 256)           525312
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 11, 5047)          1297079
# =================================================================
# Total params: 5,738,167
# Trainable params: 5,738,167
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 34000 samples, validate on 2000 samples
# Epoch 1/1000
#  - 20s - loss: 3.4007 - val_loss: 2.8969
#
# Epoch 00001: val_loss improved from inf to 2.89688, saving model to model32k.h5
# Epoch 2/1000
#  - 17s - loss: 2.7964 - val_loss: 2.7802
#
# Epoch 00002: val_loss improved from 2.89688 to 2.78023, saving model to model32k.h5
# Epoch 3/1000
#  - 17s - loss: 2.6906 - val_loss: 2.7144
#
# Epoch 00003: val_loss improved from 2.78023 to 2.71437, saving model to model32k.h5
# Epoch 4/1000
#  - 17s - loss: 2.5860 - val_loss: 2.6094
#
# Epoch 00004: val_loss improved from 2.71437 to 2.60940, saving model to model32k.h5
# Epoch 5/1000
#  - 17s - loss: 2.4732 - val_loss: 2.5299
#
# Epoch 00005: val_loss improved from 2.60940 to 2.52988, saving model to model32k.h5
# Epoch 6/1000
#  - 17s - loss: 2.3613 - val_loss: 2.4104
#
# Epoch 00006: val_loss improved from 2.52988 to 2.41045, saving model to model32k.h5
# Epoch 7/1000
#  - 17s - loss: 2.2238 - val_loss: 2.2956
#
# Epoch 00007: val_loss improved from 2.41045 to 2.29558, saving model to model32k.h5
# Epoch 8/1000
#  - 17s - loss: 2.0913 - val_loss: 2.1819
#
# Epoch 00008: val_loss improved from 2.29558 to 2.18192, saving model to model32k.h5
# Epoch 9/1000
#  - 17s - loss: 1.9617 - val_loss: 2.0697
#
# Epoch 00009: val_loss improved from 2.18192 to 2.06965, saving model to model32k.h5
# Epoch 10/1000
#  - 17s - loss: 1.8310 - val_loss: 1.9708
#
# Epoch 00010: val_loss improved from 2.06965 to 1.97081, saving model to model32k.h5
# Epoch 11/1000
#  - 17s - loss: 1.7026 - val_loss: 1.8714
#
# Epoch 00011: val_loss improved from 1.97081 to 1.87142, saving model to model32k.h5
# Epoch 12/1000
#  - 17s - loss: 1.5749 - val_loss: 1.7817
#
# Epoch 00012: val_loss improved from 1.87142 to 1.78170, saving model to model32k.h5
# Epoch 13/1000
#  - 17s - loss: 1.4499 - val_loss: 1.6929
#
# Epoch 00013: val_loss improved from 1.78170 to 1.69291, saving model to model32k.h5
# Epoch 14/1000
#  - 17s - loss: 1.3280 - val_loss: 1.6101
#
# Epoch 00014: val_loss improved from 1.69291 to 1.61014, saving model to model32k.h5
# Epoch 15/1000
#  - 17s - loss: 1.2120 - val_loss: 1.5263
#
# Epoch 00015: val_loss improved from 1.61014 to 1.52633, saving model to model32k.h5
# Epoch 16/1000
#  - 17s - loss: 1.0993 - val_loss: 1.4531
#
# Epoch 00016: val_loss improved from 1.52633 to 1.45312, saving model to model32k.h5
# Epoch 17/1000
#  - 17s - loss: 0.9959 - val_loss: 1.3862
#
# Epoch 00017: val_loss improved from 1.45312 to 1.38615, saving model to model32k.h5
# Epoch 18/1000
#  - 17s - loss: 0.9009 - val_loss: 1.3303
#
# Epoch 00018: val_loss improved from 1.38615 to 1.33027, saving model to model32k.h5
# Epoch 19/1000
#  - 17s - loss: 0.8151 - val_loss: 1.2792
#
# Epoch 00019: val_loss improved from 1.33027 to 1.27924, saving model to model32k.h5
# Epoch 20/1000
#  - 17s - loss: 0.7368 - val_loss: 1.2340
#
# Epoch 00020: val_loss improved from 1.27924 to 1.23398, saving model to model32k.h5
# Epoch 21/1000
#  - 17s - loss: 0.6642 - val_loss: 1.2029
#
# Epoch 00021: val_loss improved from 1.23398 to 1.20290, saving model to model32k.h5
# Epoch 22/1000
#  - 17s - loss: 0.6011 - val_loss: 1.1704
#
# Epoch 00022: val_loss improved from 1.20290 to 1.17036, saving model to model32k.h5
# Epoch 23/1000
#  - 17s - loss: 0.5453 - val_loss: 1.1364
#
# Epoch 00023: val_loss improved from 1.17036 to 1.13643, saving model to model32k.h5
# Epoch 24/1000
#  - 17s - loss: 0.4943 - val_loss: 1.1198
#
# Epoch 00024: val_loss improved from 1.13643 to 1.11985, saving model to model32k.h5
# Epoch 25/1000
#  - 17s - loss: 0.4494 - val_loss: 1.1005
#
# Epoch 00025: val_loss improved from 1.11985 to 1.10051, saving model to model32k.h5
# Epoch 26/1000
#  - 17s - loss: 0.4106 - val_loss: 1.0862
#
# Epoch 00026: val_loss improved from 1.10051 to 1.08618, saving model to model32k.h5
# Epoch 27/1000
#  - 17s - loss: 0.3749 - val_loss: 1.0687
#
# Epoch 00027: val_loss improved from 1.08618 to 1.06874, saving model to model32k.h5
# Epoch 28/1000
#  - 17s - loss: 0.3418 - val_loss: 1.0634
#
# Epoch 00028: val_loss improved from 1.06874 to 1.06341, saving model to model32k.h5
# Epoch 29/1000
#  - 17s - loss: 0.3141 - val_loss: 1.0487
#
# Epoch 00029: val_loss improved from 1.06341 to 1.04872, saving model to model32k.h5
# Epoch 30/1000
#  - 17s - loss: 0.2867 - val_loss: 1.0474
#
# Epoch 00030: val_loss improved from 1.04872 to 1.04744, saving model to model32k.h5
# Epoch 31/1000
#  - 17s - loss: 0.2631 - val_loss: 1.0314
#
# Epoch 00031: val_loss improved from 1.04744 to 1.03139, saving model to model32k.h5
# Epoch 32/1000
#  - 17s - loss: 0.2460 - val_loss: 1.0365
#
# Epoch 00032: val_loss did not improve from 1.03139
# Epoch 33/1000
#  - 17s - loss: 0.2261 - val_loss: 1.0263
#
# Epoch 00033: val_loss improved from 1.03139 to 1.02634, saving model to model32k.h5
# Epoch 34/1000
#  - 17s - loss: 0.2065 - val_loss: 1.0195
#
# Epoch 00034: val_loss improved from 1.02634 to 1.01947, saving model to model32k.h5
# Epoch 35/1000
#  - 17s - loss: 0.1898 - val_loss: 1.0145
#
# Epoch 00035: val_loss improved from 1.01947 to 1.01448, saving model to model32k.h5
# Epoch 36/1000
#  - 17s - loss: 0.1768 - val_loss: 1.0176
#
# Epoch 00036: val_loss did not improve from 1.01448
# Epoch 37/1000
#  - 17s - loss: 0.1668 - val_loss: 1.0144
#
# Epoch 00037: val_loss improved from 1.01448 to 1.01439, saving model to model32k.h5
# Epoch 38/1000
#  - 17s - loss: 0.1547 - val_loss: 1.0251
#
# Epoch 00038: val_loss did not improve from 1.01439
# Epoch 39/1000
#  - 17s - loss: 0.1455 - val_loss: 1.0168
#
# Epoch 00039: val_loss did not improve from 1.01439
# Epoch 40/1000
#  - 17s - loss: 0.1347 - val_loss: 1.0136
#
# Epoch 00040: val_loss improved from 1.01439 to 1.01360, saving model to model32k.h5
# Epoch 41/1000
#  - 17s - loss: 0.1257 - val_loss: 1.0235
#
# Epoch 00041: val_loss did not improve from 1.01360
# Epoch 42/1000
#  - 17s - loss: 0.1208 - val_loss: 1.0224
#
# Epoch 00042: val_loss did not improve from 1.01360
# Epoch 43/1000
#  - 17s - loss: 0.1149 - val_loss: 1.0230
#
# Epoch 00043: val_loss did not improve from 1.01360
# Epoch 44/1000
#  - 17s - loss: 0.1086 - val_loss: 1.0281
#
# Epoch 00044: val_loss did not improve from 1.01360
# Epoch 45/1000
#  - 17s - loss: 0.1011 - val_loss: 1.0311
#
# Epoch 00045: val_loss did not improve from 1.01360
# Epoch 46/1000
#  - 17s - loss: 0.0937 - val_loss: 1.0300
#
# Epoch 00046: val_loss did not improve from 1.01360
# Epoch 47/1000
#  - 17s - loss: 0.0917 - val_loss: 1.0314
#
# Epoch 00047: val_loss did not improve from 1.01360
# Epoch 48/1000
#  - 17s - loss: 0.0887 - val_loss: 1.0353
#
# Epoch 00048: val_loss did not improve from 1.01360
# Epoch 49/1000
#  - 17s - loss: 0.0862 - val_loss: 1.0373
#
# Epoch 00049: val_loss did not improve from 1.01360
# Epoch 50/1000
#  - 17s - loss: 0.0790 - val_loss: 1.0396
#
# Epoch 00050: val_loss did not improve from 1.01360
# Epoch 51/1000
#  - 17s - loss: 0.0745 - val_loss: 1.0451
#
# Epoch 00051: val_loss did not improve from 1.01360
# Epoch 52/1000
#  - 17s - loss: 0.0715 - val_loss: 1.0406
#
# Epoch 00052: val_loss did not improve from 1.01360
# Epoch 53/1000
#  - 17s - loss: 0.0693 - val_loss: 1.0492
#
# Epoch 00053: val_loss did not improve from 1.01360
# Epoch 54/1000
#  - 17s - loss: 0.0681 - val_loss: 1.0492
#
# Epoch 00054: val_loss did not improve from 1.01360
# Epoch 55/1000
#  - 17s - loss: 0.0657 - val_loss: 1.0633
#
# Epoch 00055: val_loss did not improve from 1.01360
# Epoch 56/1000
#  - 17s - loss: 0.0640 - val_loss: 1.0599
#
# Epoch 00056: val_loss did not improve from 1.01360
# Epoch 57/1000
#  - 17s - loss: 0.0605 - val_loss: 1.0646
#
# Epoch 00057: val_loss did not improve from 1.01360
# Epoch 58/1000
#  - 17s - loss: 0.0613 - val_loss: 1.0652
#
# Epoch 00058: val_loss did not improve from 1.01360
# Epoch 59/1000
#  - 17s - loss: 0.0616 - val_loss: 1.0713
#
# Epoch 00059: val_loss did not improve from 1.01360
# Epoch 60/1000
#  - 17s - loss: 0.0631 - val_loss: 1.0705
#
# Epoch 00060: val_loss did not improve from 1.01360
# Epoch 61/1000
#  - 17s - loss: 0.0610 - val_loss: 1.0857
#
# Epoch 00061: val_loss did not improve from 1.01360
# Epoch 62/1000
#  - 17s - loss: 0.0559 - val_loss: 1.0721
#
# Epoch 00062: val_loss did not improve from 1.01360
# Epoch 63/1000
#  - 17s - loss: 0.0504 - val_loss: 1.0725
#
# Epoch 00063: val_loss did not improve from 1.01360
# Epoch 64/1000
#  - 17s - loss: 0.0473 - val_loss: 1.0805
#
# Epoch 00064: val_loss did not improve from 1.01360
# Epoch 65/1000
#  - 17s - loss: 0.0471 - val_loss: 1.0855
#
# Epoch 00065: val_loss did not improve from 1.01360
# Epoch 66/1000
#  - 17s - loss: 0.0483 - val_loss: 1.0839
#
# Epoch 00066: val_loss did not improve from 1.01360
# Epoch 67/1000
#  - 17s - loss: 0.0472 - val_loss: 1.0836
#
# Epoch 00067: val_loss did not improve from 1.01360
# Epoch 68/1000
#  - 17s - loss: 0.0494 - val_loss: 1.0996
#
# Epoch 00068: val_loss did not improve from 1.01360
# Epoch 69/1000
#  - 17s - loss: 0.0539 - val_loss: 1.0961
#
# Epoch 00069: val_loss did not improve from 1.01360
# Epoch 70/1000
#  - 17s - loss: 0.0513 - val_loss: 1.0993
#
# Epoch 00070: val_loss did not improve from 1.01360
# Epoch 71/1000
#  - 17s - loss: 0.0462 - val_loss: 1.0991
#
# Epoch 00071: val_loss did not improve from 1.01360
# Epoch 72/1000
#  - 17s - loss: 0.0412 - val_loss: 1.0863
#
# Epoch 00072: val_loss did not improve from 1.01360
# Epoch 73/1000
#  - 17s - loss: 0.0390 - val_loss: 1.0982
#
# Epoch 00073: val_loss did not improve from 1.01360
# Epoch 74/1000
#  - 17s - loss: 0.0377 - val_loss: 1.0985
#
# Epoch 00074: val_loss did not improve from 1.01360
# Epoch 75/1000
#  - 17s - loss: 0.0369 - val_loss: 1.1095
#
# Epoch 00075: val_loss did not improve from 1.01360
# Epoch 76/1000
#  - 17s - loss: 0.0379 - val_loss: 1.1059
#
# Epoch 00076: val_loss did not improve from 1.01360
# Epoch 77/1000
#  - 17s - loss: 0.0424 - val_loss: 1.1243
#
# Epoch 00077: val_loss did not improve from 1.01360
# Epoch 78/1000
#  - 17s - loss: 0.0618 - val_loss: 1.1414
#
# Epoch 00078: val_loss did not improve from 1.01360
# Epoch 79/1000
#  - 17s - loss: 0.0661 - val_loss: 1.1291
#
# Epoch 00079: val_loss did not improve from 1.01360
# Epoch 80/1000
#  - 17s - loss: 0.0473 - val_loss: 1.1144
#
# Epoch 00080: val_loss did not improve from 1.01360
# Epoch 81/1000
#  - 17s - loss: 0.0362 - val_loss: 1.1150
#
# Epoch 00081: val_loss did not improve from 1.01360
# Epoch 82/1000
#  - 17s - loss: 0.0316 - val_loss: 1.1082
#
# Epoch 00082: val_loss did not improve from 1.01360
# Epoch 83/1000
#  - 17s - loss: 0.0292 - val_loss: 1.1122
#
# Epoch 00083: val_loss did not improve from 1.01360
# Epoch 84/1000
#  - 17s - loss: 0.0280 - val_loss: 1.1126
#
# Epoch 00084: val_loss did not improve from 1.01360
# Epoch 85/1000
#  - 17s - loss: 0.0289 - val_loss: 1.1238
#
# Epoch 00085: val_loss did not improve from 1.01360
# Epoch 86/1000
#  - 17s - loss: 0.0317 - val_loss: 1.1272
#
# Epoch 00086: val_loss did not improve from 1.01360
# Epoch 87/1000
#  - 17s - loss: 0.0368 - val_loss: 1.1348
#
# Epoch 00087: val_loss did not improve from 1.01360
# Epoch 88/1000
#  - 17s - loss: 0.0576 - val_loss: 1.1559
#
# Epoch 00088: val_loss did not improve from 1.01360
# Epoch 89/1000
#  - 17s - loss: 0.0649 - val_loss: 1.1519
#
# Epoch 00089: val_loss did not improve from 1.01360
# Epoch 90/1000
#  - 17s - loss: 0.0470 - val_loss: 1.1350
#
# Epoch 00090: val_loss did not improve from 1.01360
# Epoch 91/1000
#  - 17s - loss: 0.0349 - val_loss: 1.1320
#
# Epoch 00091: val_loss did not improve from 1.01360
# Epoch 92/1000
#  - 17s - loss: 0.0290 - val_loss: 1.1322
#
# Epoch 00092: val_loss did not improve from 1.01360
# Epoch 93/1000
#  - 17s - loss: 0.0272 - val_loss: 1.1347
#
# Epoch 00093: val_loss did not improve from 1.01360
# Epoch 94/1000
#  - 17s - loss: 0.0257 - val_loss: 1.1334
#
# Epoch 00094: val_loss did not improve from 1.01360
# Epoch 95/1000
#  - 17s - loss: 0.0258 - val_loss: 1.1390
#
# Epoch 00095: val_loss did not improve from 1.01360
# Epoch 96/1000
#  - 17s - loss: 0.0279 - val_loss: 1.1419
#
# Epoch 00096: val_loss did not improve from 1.01360
# Epoch 97/1000
#  - 17s - loss: 0.0352 - val_loss: 1.1543
#
# Epoch 00097: val_loss did not improve from 1.01360
# Epoch 98/1000
#  - 17s - loss: 0.0689 - val_loss: 1.1717
#
# Epoch 00098: val_loss did not improve from 1.01360
# Epoch 99/1000
#  - 17s - loss: 0.0531 - val_loss: 1.1523
#
# Epoch 00099: val_loss did not improve from 1.01360
# Epoch 100/1000
#  - 17s - loss: 0.0392 - val_loss: 1.1508
#
# Epoch 00100: val_loss did not improve from 1.01360
# Epoch 101/1000
#  - 17s - loss: 0.0326 - val_loss: 1.1475
#
# Epoch 00101: val_loss did not improve from 1.01360
# Epoch 102/1000
#  - 17s - loss: 0.0269 - val_loss: 1.1438
#
# Epoch 00102: val_loss did not improve from 1.01360
# Epoch 103/1000
#  - 17s - loss: 0.0252 - val_loss: 1.1411
#
# Epoch 00103: val_loss did not improve from 1.01360
# Epoch 104/1000
#  - 17s - loss: 0.0248 - val_loss: 1.1469
#
# Epoch 00104: val_loss did not improve from 1.01360
# Epoch 105/1000
#  - 17s - loss: 0.0246 - val_loss: 1.1483
#
# Epoch 00105: val_loss did not improve from 1.01360
# Epoch 106/1000
#  - 17s - loss: 0.0248 - val_loss: 1.1463
#
# Epoch 00106: val_loss did not improve from 1.01360
# Epoch 107/1000
#  - 17s - loss: 0.0252 - val_loss: 1.1447
#
# Epoch 00107: val_loss did not improve from 1.01360
# Epoch 108/1000
#  - 17s - loss: 0.0281 - val_loss: 1.1528
#
# Epoch 00108: val_loss did not improve from 1.01360
# Epoch 109/1000
#  - 17s - loss: 0.0640 - val_loss: 1.1877
#
# Epoch 00109: val_loss did not improve from 1.01360
# Epoch 110/1000
#  - 17s - loss: 0.0638 - val_loss: 1.1715
#
# Epoch 00110: val_loss did not improve from 1.01360
# Epoch 111/1000
#  - 17s - loss: 0.0414 - val_loss: 1.1547
#
# Epoch 00111: val_loss did not improve from 1.01360
# Epoch 112/1000
#  - 17s - loss: 0.0305 - val_loss: 1.1493
#
# Epoch 00112: val_loss did not improve from 1.01360
# Epoch 113/1000
#  - 17s - loss: 0.0259 - val_loss: 1.1442
#
# Epoch 00113: val_loss did not improve from 1.01360
# Epoch 114/1000
#  - 17s - loss: 0.0241 - val_loss: 1.1518
#
# Epoch 00114: val_loss did not improve from 1.01360
# Epoch 115/1000
#  - 17s - loss: 0.0235 - val_loss: 1.1533
#
# Epoch 00115: val_loss did not improve from 1.01360
# Epoch 116/1000
#  - 17s - loss: 0.0232 - val_loss: 1.1573
#
# Epoch 00116: val_loss did not improve from 1.01360
# Epoch 117/1000
#  - 17s - loss: 0.0237 - val_loss: 1.1542
#
# Epoch 00117: val_loss did not improve from 1.01360
# Epoch 118/1000
#  - 17s - loss: 0.0251 - val_loss: 1.1639
#
# Epoch 00118: val_loss did not improve from 1.01360
# Epoch 119/1000
#  - 17s - loss: 0.0308 - val_loss: 1.1695
#
# Epoch 00119: val_loss did not improve from 1.01360
# Epoch 120/1000
#  - 17s - loss: 0.0596 - val_loss: 1.2046
#
# Epoch 00120: val_loss did not improve from 1.01360
# Epoch 121/1000
#  - 17s - loss: 0.0560 - val_loss: 1.1726
#
# Epoch 00121: val_loss did not improve from 1.01360
# Epoch 122/1000
#  - 17s - loss: 0.0368 - val_loss: 1.1587
#
# Epoch 00122: val_loss did not improve from 1.01360
# Epoch 123/1000
#  - 17s - loss: 0.0281 - val_loss: 1.1619
#
# Epoch 00123: val_loss did not improve from 1.01360
# Epoch 124/1000
#  - 17s - loss: 0.0249 - val_loss: 1.1592
#
# Epoch 00124: val_loss did not improve from 1.01360
# Epoch 125/1000
#  - 17s - loss: 0.0237 - val_loss: 1.1582
#
# Epoch 00125: val_loss did not improve from 1.01360
# Epoch 126/1000
#  - 17s - loss: 0.0235 - val_loss: 1.1570
#
# Epoch 00126: val_loss did not improve from 1.01360
# Epoch 127/1000
#  - 17s - loss: 0.0233 - val_loss: 1.1583
#
# Epoch 00127: val_loss did not improve from 1.01360
# Epoch 128/1000
#  - 17s - loss: 0.0239 - val_loss: 1.1668
#
# Epoch 00128: val_loss did not improve from 1.01360
# Epoch 129/1000
#  - 17s - loss: 0.0252 - val_loss: 1.1723
#
# Epoch 00129: val_loss did not improve from 1.01360
# Epoch 130/1000
#  - 17s - loss: 0.0278 - val_loss: 1.1849
#
# Epoch 00130: val_loss did not improve from 1.01360
# Epoch 131/1000
#  - 17s - loss: 0.0497 - val_loss: 1.2004
#
# Epoch 00131: val_loss did not improve from 1.01360
# Epoch 132/1000
#  - 17s - loss: 0.0512 - val_loss: 1.1880
#
# Epoch 00132: val_loss did not improve from 1.01360
# Epoch 133/1000
#  - 17s - loss: 0.0364 - val_loss: 1.1865
#
# Epoch 00133: val_loss did not improve from 1.01360
# Epoch 134/1000
#  - 17s - loss: 0.0280 - val_loss: 1.1830
#
# Epoch 00134: val_loss did not improve from 1.01360
# Epoch 135/1000
#  - 17s - loss: 0.0255 - val_loss: 1.1754
#
# Epoch 00135: val_loss did not improve from 1.01360
# Epoch 136/1000
#  - 17s - loss: 0.0252 - val_loss: 1.1769
#
# Epoch 00136: val_loss did not improve from 1.01360
# Epoch 137/1000
#  - 17s - loss: 0.0238 - val_loss: 1.1788
#
# Epoch 00137: val_loss did not improve from 1.01360
# Epoch 138/1000
#  - 17s - loss: 0.0232 - val_loss: 1.1812
#
# Epoch 00138: val_loss did not improve from 1.01360
# Epoch 139/1000
#  - 17s - loss: 0.0227 - val_loss: 1.1818
#
# Epoch 00139: val_loss did not improve from 1.01360
# Epoch 140/1000
#  - 17s - loss: 0.0231 - val_loss: 1.1797
#
# Epoch 00140: val_loss did not improve from 1.01360
# Epoch 141/1000
#  - 17s - loss: 0.0239 - val_loss: 1.1865
#
# Epoch 00141: val_loss did not improve from 1.01360
# Epoch 142/1000
#  - 17s - loss: 0.0306 - val_loss: 1.2068
#
# Epoch 00142: val_loss did not improve from 1.01360
# Epoch 143/1000
#  - 17s - loss: 0.0597 - val_loss: 1.2231
#
# Epoch 00143: val_loss did not improve from 1.01360
# Epoch 144/1000
#  - 17s - loss: 0.0538 - val_loss: 1.1970
#
# Epoch 00144: val_loss did not improve from 1.01360
# Epoch 145/1000
#  - 17s - loss: 0.0359 - val_loss: 1.1803
#
# Epoch 00145: val_loss did not improve from 1.01360
# Epoch 146/1000
#  - 17s - loss: 0.0260 - val_loss: 1.1811
#
# Epoch 00146: val_loss did not improve from 1.01360
# Epoch 147/1000
#  - 17s - loss: 0.0230 - val_loss: 1.1824
#
# Epoch 00147: val_loss did not improve from 1.01360
# Epoch 148/1000
#  - 17s - loss: 0.0225 - val_loss: 1.1779
#
# Epoch 00148: val_loss did not improve from 1.01360
# Epoch 149/1000
#  - 17s - loss: 0.0219 - val_loss: 1.1828
#
# Epoch 00149: val_loss did not improve from 1.01360
# Epoch 150/1000
#  - 17s - loss: 0.0217 - val_loss: 1.1813
#
# Epoch 00150: val_loss did not improve from 1.01360
# Epoch 151/1000
#  - 17s - loss: 0.0221 - val_loss: 1.1818
#
# Epoch 00151: val_loss did not improve from 1.01360
# Epoch 152/1000
#  - 17s - loss: 0.0222 - val_loss: 1.1839
#
# Epoch 00152: val_loss did not improve from 1.01360
# Epoch 153/1000
#  - 17s - loss: 0.0227 - val_loss: 1.1857
#
# Epoch 00153: val_loss did not improve from 1.01360
# Epoch 154/1000
#  - 17s - loss: 0.0235 - val_loss: 1.1842
#
# Epoch 00154: val_loss did not improve from 1.01360
# Epoch 155/1000
#  - 17s - loss: 0.0265 - val_loss: 1.2036
#
# Epoch 00155: val_loss did not improve from 1.01360
# Epoch 156/1000
#  - 17s - loss: 0.0552 - val_loss: 1.2319
#
# Epoch 00156: val_loss did not improve from 1.01360
# Epoch 157/1000
#  - 17s - loss: 0.0529 - val_loss: 1.2084
#
# Epoch 00157: val_loss did not improve from 1.01360
# Epoch 158/1000
#  - 17s - loss: 0.0340 - val_loss: 1.1927
#
# Epoch 00158: val_loss did not improve from 1.01360
# Epoch 159/1000
#  - 17s - loss: 0.0257 - val_loss: 1.2006
#
# Epoch 00159: val_loss did not improve from 1.01360
# Epoch 160/1000
#  - 17s - loss: 0.0231 - val_loss: 1.1915
#
# Epoch 00160: val_loss did not improve from 1.01360
# Epoch 161/1000
#  - 17s - loss: 0.0219 - val_loss: 1.1908
#
# Epoch 00161: val_loss did not improve from 1.01360
# Epoch 162/1000
#  - 17s - loss: 0.0216 - val_loss: 1.1929
#
# Epoch 00162: val_loss did not improve from 1.01360
# Epoch 163/1000
#  - 17s - loss: 0.0217 - val_loss: 1.1916
#
# Epoch 00163: val_loss did not improve from 1.01360
# Epoch 164/1000
#  - 17s - loss: 0.0216 - val_loss: 1.1897
#
# Epoch 00164: val_loss did not improve from 1.01360
# Epoch 165/1000
#  - 17s - loss: 0.0218 - val_loss: 1.1960
#
# Epoch 00165: val_loss did not improve from 1.01360
# Epoch 166/1000
#  - 17s - loss: 0.0221 - val_loss: 1.1945
#
# Epoch 00166: val_loss did not improve from 1.01360
# Epoch 167/1000
#  - 17s - loss: 0.0238 - val_loss: 1.2012
#
# Epoch 00167: val_loss did not improve from 1.01360
# Epoch 168/1000
#  - 17s - loss: 0.0486 - val_loss: 1.2435
#
# Epoch 00168: val_loss did not improve from 1.01360
# Epoch 169/1000
#  - 17s - loss: 0.0579 - val_loss: 1.2166
#
# Epoch 00169: val_loss did not improve from 1.01360
# Epoch 170/1000
#  - 17s - loss: 0.0352 - val_loss: 1.2071
#
# Epoch 00170: val_loss did not improve from 1.01360
# Epoch 171/1000
#  - 17s - loss: 0.0260 - val_loss: 1.1942
#
# Epoch 00171: val_loss did not improve from 1.01360
# Epoch 172/1000
#  - 17s - loss: 0.0231 - val_loss: 1.1991
#
# Epoch 00172: val_loss did not improve from 1.01360
# Epoch 173/1000
#  - 17s - loss: 0.0219 - val_loss: 1.1932
#
# Epoch 00173: val_loss did not improve from 1.01360
# Epoch 174/1000
#  - 17s - loss: 0.0214 - val_loss: 1.2010
#
# Epoch 00174: val_loss did not improve from 1.01360
# Epoch 175/1000
#  - 17s - loss: 0.0214 - val_loss: 1.2031
#
# Epoch 00175: val_loss did not improve from 1.01360
# Epoch 176/1000
#  - 17s - loss: 0.0214 - val_loss: 1.1992
#
# Epoch 00176: val_loss did not improve from 1.01360
# Epoch 177/1000
#  - 17s - loss: 0.0213 - val_loss: 1.1991
#
# Epoch 00177: val_loss did not improve from 1.01360
# Epoch 178/1000
#  - 17s - loss: 0.0219 - val_loss: 1.2073
#
# Epoch 00178: val_loss did not improve from 1.01360
# Epoch 179/1000
#  - 17s - loss: 0.0221 - val_loss: 1.1987
#
# Epoch 00179: val_loss did not improve from 1.01360
# Epoch 180/1000
#  - 17s - loss: 0.0231 - val_loss: 1.2109
#
# Epoch 00180: val_loss did not improve from 1.01360
# Epoch 181/1000
#  - 17s - loss: 0.0472 - val_loss: 1.2591
#
# Epoch 00181: val_loss did not improve from 1.01360
# Epoch 182/1000
#  - 17s - loss: 0.0616 - val_loss: 1.2366
#
# Epoch 00182: val_loss did not improve from 1.01360
# Epoch 183/1000
#  - 17s - loss: 0.0374 - val_loss: 1.2123
#
# Epoch 00183: val_loss did not improve from 1.01360
# Epoch 184/1000
#  - 17s - loss: 0.0266 - val_loss: 1.2152
#
# Epoch 00184: val_loss did not improve from 1.01360
# Epoch 185/1000
#  - 17s - loss: 0.0228 - val_loss: 1.2131
#
# Epoch 00185: val_loss did not improve from 1.01360
# Epoch 186/1000
#  - 17s - loss: 0.0215 - val_loss: 1.2152
#
# Epoch 00186: val_loss did not improve from 1.01360
# Epoch 187/1000
#  - 17s - loss: 0.0209 - val_loss: 1.2088
#
# Epoch 00187: val_loss did not improve from 1.01360
# Epoch 188/1000
#  - 17s - loss: 0.0207 - val_loss: 1.2191
#
# Epoch 00188: val_loss did not improve from 1.01360
# Epoch 189/1000
#  - 17s - loss: 0.0210 - val_loss: 1.2158
#
# Epoch 00189: val_loss did not improve from 1.01360
# Epoch 190/1000
#  - 17s - loss: 0.0212 - val_loss: 1.2138
#
# Epoch 00190: val_loss did not improve from 1.01360
# Epoch 191/1000
#  - 17s - loss: 0.0213 - val_loss: 1.2058
#
# Epoch 00191: val_loss did not improve from 1.01360
# Epoch 192/1000
#  - 17s - loss: 0.0215 - val_loss: 1.2148
#
# Epoch 00192: val_loss did not improve from 1.01360
# Epoch 193/1000
#  - 17s - loss: 0.0221 - val_loss: 1.2169
#
# Epoch 00193: val_loss did not improve from 1.01360
# Epoch 194/1000
#  - 17s - loss: 0.0462 - val_loss: 1.2641
#
# Epoch 00194: val_loss did not improve from 1.01360
# Epoch 195/1000
#  - 17s - loss: 0.0507 - val_loss: 1.2310
#
# Epoch 00195: val_loss did not improve from 1.01360
# Epoch 196/1000
#  - 17s - loss: 0.0340 - val_loss: 1.2170
#
# Epoch 00196: val_loss did not improve from 1.01360
# Epoch 197/1000
#  - 17s - loss: 0.0274 - val_loss: 1.2138
#
# Epoch 00197: val_loss did not improve from 1.01360
# Epoch 198/1000
#  - 17s - loss: 0.0232 - val_loss: 1.2058
#
# Epoch 00198: val_loss did not improve from 1.01360
# Epoch 199/1000
#  - 17s - loss: 0.0216 - val_loss: 1.2102
#
# Epoch 00199: val_loss did not improve from 1.01360
# Epoch 200/1000
#  - 17s - loss: 0.0208 - val_loss: 1.2123
#
# Epoch 00200: val_loss did not improve from 1.01360
# Epoch 201/1000
#  - 17s - loss: 0.0207 - val_loss: 1.2152
#
# Epoch 00201: val_loss did not improve from 1.01360
# Epoch 202/1000
#  - 17s - loss: 0.0209 - val_loss: 1.2120
#
# Epoch 00202: val_loss did not improve from 1.01360
# Epoch 203/1000
#  - 17s - loss: 0.0210 - val_loss: 1.2178
#
# Epoch 00203: val_loss did not improve from 1.01360
# Epoch 204/1000
#  - 17s - loss: 0.0211 - val_loss: 1.2155
#
# Epoch 00204: val_loss did not improve from 1.01360
# Epoch 205/1000
#  - 17s - loss: 0.0214 - val_loss: 1.2191
#
# Epoch 00205: val_loss did not improve from 1.01360
# Epoch 206/1000
#  - 17s - loss: 0.0220 - val_loss: 1.2216
#
# Epoch 00206: val_loss did not improve from 1.01360
# Epoch 207/1000
#  - 17s - loss: 0.0275 - val_loss: 1.2436
#
# Epoch 00207: val_loss did not improve from 1.01360
# Epoch 208/1000
#  - 17s - loss: 0.0613 - val_loss: 1.2494
#
# Epoch 00208: val_loss did not improve from 1.01360
# Epoch 209/1000
#  - 17s - loss: 0.0441 - val_loss: 1.2331
#
# Epoch 00209: val_loss did not improve from 1.01360
# Epoch 210/1000
#  - 17s - loss: 0.0288 - val_loss: 1.2189
#
# Epoch 00210: val_loss did not improve from 1.01360
# Epoch 211/1000
#  - 17s - loss: 0.0231 - val_loss: 1.2249
#
# Epoch 00211: val_loss did not improve from 1.01360
# Epoch 212/1000
#  - 17s - loss: 0.0215 - val_loss: 1.2225
#
# Epoch 00212: val_loss did not improve from 1.01360
# Epoch 213/1000
#  - 17s - loss: 0.0206 - val_loss: 1.2211
#
# Epoch 00213: val_loss did not improve from 1.01360
# Epoch 214/1000
#  - 17s - loss: 0.0204 - val_loss: 1.2217
#
# Epoch 00214: val_loss did not improve from 1.01360
# Epoch 215/1000
#  - 17s - loss: 0.0205 - val_loss: 1.2218
#
# Epoch 00215: val_loss did not improve from 1.01360
# Epoch 216/1000
#  - 17s - loss: 0.0204 - val_loss: 1.2289
#
# Epoch 00216: val_loss did not improve from 1.01360
# Epoch 217/1000
#  - 17s - loss: 0.0206 - val_loss: 1.2223
#
# Epoch 00217: val_loss did not improve from 1.01360
# Epoch 218/1000
#  - 17s - loss: 0.0211 - val_loss: 1.2241
#
# Epoch 00218: val_loss did not improve from 1.01360
# Epoch 219/1000
#  - 17s - loss: 0.0215 - val_loss: 1.2285
#
# Epoch 00219: val_loss did not improve from 1.01360
# Epoch 220/1000
#  - 17s - loss: 0.0242 - val_loss: 1.2487
#
# Epoch 00220: val_loss did not improve from 1.01360
# Epoch 221/1000
#  - 17s - loss: 0.0436 - val_loss: 1.2622
#
# Epoch 00221: val_loss did not improve from 1.01360
# Epoch 222/1000
#  - 17s - loss: 0.0466 - val_loss: 1.2473
#
# Epoch 00222: val_loss did not improve from 1.01360
# Epoch 223/1000
#  - 17s - loss: 0.0347 - val_loss: 1.2353
#
# Epoch 00223: val_loss did not improve from 1.01360
# Epoch 224/1000
#  - 17s - loss: 0.0263 - val_loss: 1.2297
#
# Epoch 00224: val_loss did not improve from 1.01360
# Epoch 225/1000
#  - 17s - loss: 0.0225 - val_loss: 1.2266
#
# Epoch 00225: val_loss did not improve from 1.01360
# Epoch 226/1000
#  - 17s - loss: 0.0207 - val_loss: 1.2280
#
# Epoch 00226: val_loss did not improve from 1.01360
# Epoch 227/1000
#  - 17s - loss: 0.0205 - val_loss: 1.2272
#
# Epoch 00227: val_loss did not improve from 1.01360
# Epoch 228/1000
#  - 17s - loss: 0.0204 - val_loss: 1.2239
#
# Epoch 00228: val_loss did not improve from 1.01360
# Epoch 229/1000
#  - 17s - loss: 0.0203 - val_loss: 1.2279
#
# Epoch 00229: val_loss did not improve from 1.01360
# Epoch 230/1000
#  - 17s - loss: 0.0205 - val_loss: 1.2293
#
# Epoch 00230: val_loss did not improve from 1.01360
# Epoch 231/1000
#  - 17s - loss: 0.0206 - val_loss: 1.2293
#
# Epoch 00231: val_loss did not improve from 1.01360
# Epoch 232/1000
#  - 17s - loss: 0.0209 - val_loss: 1.2300
#
# Epoch 00232: val_loss did not improve from 1.01360
# Epoch 233/1000
#  - 17s - loss: 0.0275 - val_loss: 1.2511
#
# Epoch 00233: val_loss did not improve from 1.01360
# Epoch 234/1000
#  - 17s - loss: 0.0467 - val_loss: 1.2590
#
# Epoch 00234: val_loss did not improve from 1.01360
# Epoch 235/1000
#  - 17s - loss: 0.0382 - val_loss: 1.2497
#
# Epoch 00235: val_loss did not improve from 1.01360
# Epoch 236/1000
#  - 17s - loss: 0.0271 - val_loss: 1.2453
#
# Epoch 00236: val_loss did not improve from 1.01360
# Epoch 237/1000
#  - 17s - loss: 0.0231 - val_loss: 1.2411
#
# Epoch 00237: val_loss did not improve from 1.01360
# Epoch 238/1000
#  - 17s - loss: 0.0213 - val_loss: 1.2399
#
# Epoch 00238: val_loss did not improve from 1.01360
# Epoch 239/1000
#  - 17s - loss: 0.0207 - val_loss: 1.2416
#
# Epoch 00239: val_loss did not improve from 1.01360
# Epoch 240/1000
#  - 17s - loss: 0.0201 - val_loss: 1.2398
#
# Epoch 00240: val_loss did not improve from 1.01360
# Epoch 241/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2398
#
# Epoch 00241: val_loss did not improve from 1.01360
# Epoch 242/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2441
#
# Epoch 00242: val_loss did not improve from 1.01360
# Epoch 243/1000
#  - 17s - loss: 0.0206 - val_loss: 1.2393
#
# Epoch 00243: val_loss did not improve from 1.01360
# Epoch 244/1000
#  - 17s - loss: 0.0211 - val_loss: 1.2413
#
# Epoch 00244: val_loss did not improve from 1.01360
# Epoch 245/1000
#  - 17s - loss: 0.0218 - val_loss: 1.2377
#
# Epoch 00245: val_loss did not improve from 1.01360
# Epoch 246/1000
#  - 17s - loss: 0.0257 - val_loss: 1.2595
#
# Epoch 00246: val_loss did not improve from 1.01360
# Epoch 247/1000
#  - 17s - loss: 0.0452 - val_loss: 1.2733
#
# Epoch 00247: val_loss did not improve from 1.01360
# Epoch 248/1000
#  - 17s - loss: 0.0411 - val_loss: 1.2518
#
# Epoch 00248: val_loss did not improve from 1.01360
# Epoch 249/1000
#  - 17s - loss: 0.0287 - val_loss: 1.2522
#
# Epoch 00249: val_loss did not improve from 1.01360
# Epoch 250/1000
#  - 17s - loss: 0.0231 - val_loss: 1.2402
#
# Epoch 00250: val_loss did not improve from 1.01360
# Epoch 251/1000
#  - 17s - loss: 0.0211 - val_loss: 1.2424
#
# Epoch 00251: val_loss did not improve from 1.01360
# Epoch 252/1000
#  - 17s - loss: 0.0205 - val_loss: 1.2412
#
# Epoch 00252: val_loss did not improve from 1.01360
# Epoch 253/1000
#  - 17s - loss: 0.0207 - val_loss: 1.2471
#
# Epoch 00253: val_loss did not improve from 1.01360
# Epoch 254/1000
#  - 17s - loss: 0.0209 - val_loss: 1.2505
#
# Epoch 00254: val_loss did not improve from 1.01360
# Epoch 255/1000
#  - 17s - loss: 0.0208 - val_loss: 1.2477
#
# Epoch 00255: val_loss did not improve from 1.01360
# Epoch 256/1000
#  - 17s - loss: 0.0212 - val_loss: 1.2387
#
# Epoch 00256: val_loss did not improve from 1.01360
# Epoch 257/1000
#  - 17s - loss: 0.0213 - val_loss: 1.2440
#
# Epoch 00257: val_loss did not improve from 1.01360
# Epoch 258/1000
#  - 17s - loss: 0.0213 - val_loss: 1.2477
#
# Epoch 00258: val_loss did not improve from 1.01360
# Epoch 259/1000
#  - 17s - loss: 0.0220 - val_loss: 1.2466
#
# Epoch 00259: val_loss did not improve from 1.01360
# Epoch 260/1000
#  - 17s - loss: 0.0295 - val_loss: 1.2964
#
# Epoch 00260: val_loss did not improve from 1.01360
# Epoch 261/1000
#  - 17s - loss: 0.0559 - val_loss: 1.2695
#
# Epoch 00261: val_loss did not improve from 1.01360
# Epoch 262/1000
#  - 17s - loss: 0.0343 - val_loss: 1.2483
#
# Epoch 00262: val_loss did not improve from 1.01360
# Epoch 263/1000
#  - 17s - loss: 0.0248 - val_loss: 1.2418
#
# Epoch 00263: val_loss did not improve from 1.01360
# Epoch 264/1000
#  - 17s - loss: 0.0216 - val_loss: 1.2458
#
# Epoch 00264: val_loss did not improve from 1.01360
# Epoch 265/1000
#  - 17s - loss: 0.0204 - val_loss: 1.2429
#
# Epoch 00265: val_loss did not improve from 1.01360
# Epoch 266/1000
#  - 17s - loss: 0.0199 - val_loss: 1.2456
#
# Epoch 00266: val_loss did not improve from 1.01360
# Epoch 267/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2473
#
# Epoch 00267: val_loss did not improve from 1.01360
# Epoch 268/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2427
#
# Epoch 00268: val_loss did not improve from 1.01360
# Epoch 269/1000
#  - 17s - loss: 0.0200 - val_loss: 1.2478
#
# Epoch 00269: val_loss did not improve from 1.01360
# Epoch 270/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2452
#
# Epoch 00270: val_loss did not improve from 1.01360
# Epoch 271/1000
#  - 17s - loss: 0.0203 - val_loss: 1.2531
#
# Epoch 00271: val_loss did not improve from 1.01360
# Epoch 272/1000
#  - 17s - loss: 0.0209 - val_loss: 1.2598
#
# Epoch 00272: val_loss did not improve from 1.01360
# Epoch 273/1000
#  - 17s - loss: 0.0215 - val_loss: 1.2609
#
# Epoch 00273: val_loss did not improve from 1.01360
# Epoch 274/1000
#  - 17s - loss: 0.0247 - val_loss: 1.2631
#
# Epoch 00274: val_loss did not improve from 1.01360
# Epoch 275/1000
#  - 17s - loss: 0.0480 - val_loss: 1.2805
#
# Epoch 00275: val_loss did not improve from 1.01360
# Epoch 276/1000
#  - 17s - loss: 0.0408 - val_loss: 1.2674
#
# Epoch 00276: val_loss did not improve from 1.01360
# Epoch 277/1000
#  - 17s - loss: 0.0288 - val_loss: 1.2566
#
# Epoch 00277: val_loss did not improve from 1.01360
# Epoch 278/1000
#  - 17s - loss: 0.0236 - val_loss: 1.2624
#
# Epoch 00278: val_loss did not improve from 1.01360
# Epoch 279/1000
#  - 17s - loss: 0.0214 - val_loss: 1.2568
#
# Epoch 00279: val_loss did not improve from 1.01360
# Epoch 280/1000
#  - 17s - loss: 0.0206 - val_loss: 1.2579
#
# Epoch 00280: val_loss did not improve from 1.01360
# Epoch 281/1000
#  - 17s - loss: 0.0201 - val_loss: 1.2581
#
# Epoch 00281: val_loss did not improve from 1.01360
# Epoch 282/1000
#  - 17s - loss: 0.0200 - val_loss: 1.2584
#
# Epoch 00282: val_loss did not improve from 1.01360
# Epoch 283/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2600
#
# Epoch 00283: val_loss did not improve from 1.01360
# Epoch 284/1000
#  - 17s - loss: 0.0199 - val_loss: 1.2607
#
# Epoch 00284: val_loss did not improve from 1.01360
# Epoch 285/1000
#  - 17s - loss: 0.0201 - val_loss: 1.2630
#
# Epoch 00285: val_loss did not improve from 1.01360
# Epoch 286/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2624
#
# Epoch 00286: val_loss did not improve from 1.01360
# Epoch 287/1000
#  - 17s - loss: 0.0204 - val_loss: 1.2567
#
# Epoch 00287: val_loss did not improve from 1.01360
# Epoch 288/1000
#  - 17s - loss: 0.0209 - val_loss: 1.2650
#
# Epoch 00288: val_loss did not improve from 1.01360
# Epoch 289/1000
#  - 17s - loss: 0.0221 - val_loss: 1.2612
#
# Epoch 00289: val_loss did not improve from 1.01360
# Epoch 290/1000
#  - 17s - loss: 0.0389 - val_loss: 1.3107
#
# Epoch 00290: val_loss did not improve from 1.01360
# Epoch 291/1000
#  - 17s - loss: 0.0575 - val_loss: 1.2736
#
# Epoch 00291: val_loss did not improve from 1.01360
# Epoch 292/1000
#  - 17s - loss: 0.0340 - val_loss: 1.2647
#
# Epoch 00292: val_loss did not improve from 1.01360
# Epoch 293/1000
#  - 17s - loss: 0.0241 - val_loss: 1.2589
#
# Epoch 00293: val_loss did not improve from 1.01360
# Epoch 294/1000
#  - 17s - loss: 0.0208 - val_loss: 1.2536
#
# Epoch 00294: val_loss did not improve from 1.01360
# Epoch 295/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2549
#
# Epoch 00295: val_loss did not improve from 1.01360
# Epoch 296/1000
#  - 17s - loss: 0.0195 - val_loss: 1.2584
#
# Epoch 00296: val_loss did not improve from 1.01360
# Epoch 297/1000
#  - 17s - loss: 0.0195 - val_loss: 1.2613
#
# Epoch 00297: val_loss did not improve from 1.01360
# Epoch 298/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2605
#
# Epoch 00298: val_loss did not improve from 1.01360
# Epoch 299/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2613
#
# Epoch 00299: val_loss did not improve from 1.01360
# Epoch 300/1000
#  - 17s - loss: 0.0199 - val_loss: 1.2604
#
# Epoch 00300: val_loss did not improve from 1.01360
# Epoch 301/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2606
#
# Epoch 00301: val_loss did not improve from 1.01360
# Epoch 302/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2581
#
# Epoch 00302: val_loss did not improve from 1.01360
# Epoch 303/1000
#  - 17s - loss: 0.0207 - val_loss: 1.2627
#
# Epoch 00303: val_loss did not improve from 1.01360
# Epoch 304/1000
#  - 17s - loss: 0.0215 - val_loss: 1.2648
#
# Epoch 00304: val_loss did not improve from 1.01360
# Epoch 305/1000
#  - 17s - loss: 0.0380 - val_loss: 1.3098
#
# Epoch 00305: val_loss did not improve from 1.01360
# Epoch 306/1000
#  - 17s - loss: 0.0472 - val_loss: 1.2913
#
# Epoch 00306: val_loss did not improve from 1.01360
# Epoch 307/1000
#  - 17s - loss: 0.0312 - val_loss: 1.2710
#
# Epoch 00307: val_loss did not improve from 1.01360
# Epoch 308/1000
#  - 17s - loss: 0.0241 - val_loss: 1.2703
#
# Epoch 00308: val_loss did not improve from 1.01360
# Epoch 309/1000
#  - 17s - loss: 0.0213 - val_loss: 1.2711
#
# Epoch 00309: val_loss did not improve from 1.01360
# Epoch 310/1000
#  - 17s - loss: 0.0199 - val_loss: 1.2689
#
# Epoch 00310: val_loss did not improve from 1.01360
# Epoch 311/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2743
#
# Epoch 00311: val_loss did not improve from 1.01360
# Epoch 312/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2668
#
# Epoch 00312: val_loss did not improve from 1.01360
# Epoch 313/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2689
#
# Epoch 00313: val_loss did not improve from 1.01360
# Epoch 314/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2700
#
# Epoch 00314: val_loss did not improve from 1.01360
# Epoch 315/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2646
#
# Epoch 00315: val_loss did not improve from 1.01360
# Epoch 316/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2673
#
# Epoch 00316: val_loss did not improve from 1.01360
# Epoch 317/1000
#  - 17s - loss: 0.0207 - val_loss: 1.2792
#
# Epoch 00317: val_loss did not improve from 1.01360
# Epoch 318/1000
#  - 17s - loss: 0.0215 - val_loss: 1.2861
#
# Epoch 00318: val_loss did not improve from 1.01360
# Epoch 319/1000
#  - 17s - loss: 0.0309 - val_loss: 1.2955
#
# Epoch 00319: val_loss did not improve from 1.01360
# Epoch 320/1000
#  - 17s - loss: 0.0409 - val_loss: 1.2990
#
# Epoch 00320: val_loss did not improve from 1.01360
# Epoch 321/1000
#  - 17s - loss: 0.0331 - val_loss: 1.2879
#
# Epoch 00321: val_loss did not improve from 1.01360
# Epoch 322/1000
#  - 17s - loss: 0.0276 - val_loss: 1.2820
#
# Epoch 00322: val_loss did not improve from 1.01360
# Epoch 323/1000
#  - 17s - loss: 0.0227 - val_loss: 1.2762
#
# Epoch 00323: val_loss did not improve from 1.01360
# Epoch 324/1000
#  - 17s - loss: 0.0209 - val_loss: 1.2764
#
# Epoch 00324: val_loss did not improve from 1.01360
# Epoch 325/1000
#  - 17s - loss: 0.0199 - val_loss: 1.2735
#
# Epoch 00325: val_loss did not improve from 1.01360
# Epoch 326/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2745
#
# Epoch 00326: val_loss did not improve from 1.01360
# Epoch 327/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2703
#
# Epoch 00327: val_loss did not improve from 1.01360
# Epoch 328/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2777
#
# Epoch 00328: val_loss did not improve from 1.01360
# Epoch 329/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2729
#
# Epoch 00329: val_loss did not improve from 1.01360
# Epoch 330/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2775
#
# Epoch 00330: val_loss did not improve from 1.01360
# Epoch 331/1000
#  - 17s - loss: 0.0201 - val_loss: 1.2723
#
# Epoch 00331: val_loss did not improve from 1.01360
# Epoch 332/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2779
#
# Epoch 00332: val_loss did not improve from 1.01360
# Epoch 333/1000
#  - 17s - loss: 0.0217 - val_loss: 1.2900
#
# Epoch 00333: val_loss did not improve from 1.01360
# Epoch 334/1000
#  - 17s - loss: 0.0449 - val_loss: 1.3068
#
# Epoch 00334: val_loss did not improve from 1.01360
# Epoch 335/1000
#  - 17s - loss: 0.0411 - val_loss: 1.2939
#
# Epoch 00335: val_loss did not improve from 1.01360
# Epoch 336/1000
#  - 17s - loss: 0.0280 - val_loss: 1.2836
#
# Epoch 00336: val_loss did not improve from 1.01360
# Epoch 337/1000
#  - 17s - loss: 0.0224 - val_loss: 1.2841
#
# Epoch 00337: val_loss did not improve from 1.01360
# Epoch 338/1000
#  - 17s - loss: 0.0203 - val_loss: 1.2793
#
# Epoch 00338: val_loss did not improve from 1.01360
# Epoch 339/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2747
#
# Epoch 00339: val_loss did not improve from 1.01360
# Epoch 340/1000
#  - 17s - loss: 0.0191 - val_loss: 1.2781
#
# Epoch 00340: val_loss did not improve from 1.01360
# Epoch 341/1000
#  - 17s - loss: 0.0192 - val_loss: 1.2774
#
# Epoch 00341: val_loss did not improve from 1.01360
# Epoch 342/1000
#  - 17s - loss: 0.0192 - val_loss: 1.2810
#
# Epoch 00342: val_loss did not improve from 1.01360
# Epoch 343/1000
#  - 17s - loss: 0.0194 - val_loss: 1.2784
#
# Epoch 00343: val_loss did not improve from 1.01360
# Epoch 344/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2816
#
# Epoch 00344: val_loss did not improve from 1.01360
# Epoch 345/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2758
#
# Epoch 00345: val_loss did not improve from 1.01360
# Epoch 346/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2805
#
# Epoch 00346: val_loss did not improve from 1.01360
# Epoch 347/1000
#  - 17s - loss: 0.0210 - val_loss: 1.2841
#
# Epoch 00347: val_loss did not improve from 1.01360
# Epoch 348/1000
#  - 17s - loss: 0.0393 - val_loss: 1.3048
#
# Epoch 00348: val_loss did not improve from 1.01360
# Epoch 349/1000
#  - 17s - loss: 0.0422 - val_loss: 1.3084
#
# Epoch 00349: val_loss did not improve from 1.01360
# Epoch 350/1000
#  - 17s - loss: 0.0306 - val_loss: 1.2836
#
# Epoch 00350: val_loss did not improve from 1.01360
# Epoch 351/1000
#  - 17s - loss: 0.0233 - val_loss: 1.2833
#
# Epoch 00351: val_loss did not improve from 1.01360
# Epoch 352/1000
#  - 17s - loss: 0.0210 - val_loss: 1.2817
#
# Epoch 00352: val_loss did not improve from 1.01360
# Epoch 353/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2843
#
# Epoch 00353: val_loss did not improve from 1.01360
# Epoch 354/1000
#  - 17s - loss: 0.0193 - val_loss: 1.2815
#
# Epoch 00354: val_loss did not improve from 1.01360
# Epoch 355/1000
#  - 17s - loss: 0.0190 - val_loss: 1.2846
#
# Epoch 00355: val_loss did not improve from 1.01360
# Epoch 356/1000
#  - 17s - loss: 0.0194 - val_loss: 1.2801
#
# Epoch 00356: val_loss did not improve from 1.01360
# Epoch 357/1000
#  - 17s - loss: 0.0192 - val_loss: 1.2861
#
# Epoch 00357: val_loss did not improve from 1.01360
# Epoch 358/1000
#  - 17s - loss: 0.0195 - val_loss: 1.2865
#
# Epoch 00358: val_loss did not improve from 1.01360
# Epoch 359/1000
#  - 17s - loss: 0.0198 - val_loss: 1.2804
#
# Epoch 00359: val_loss did not improve from 1.01360
# Epoch 360/1000
#  - 17s - loss: 0.0206 - val_loss: 1.2997
#
# Epoch 00360: val_loss did not improve from 1.01360
# Epoch 361/1000
#  - 17s - loss: 0.0289 - val_loss: 1.3050
#
# Epoch 00361: val_loss did not improve from 1.01360
# Epoch 362/1000
#  - 17s - loss: 0.0409 - val_loss: 1.2996
#
# Epoch 00362: val_loss did not improve from 1.01360
# Epoch 363/1000
#  - 17s - loss: 0.0309 - val_loss: 1.2915
#
# Epoch 00363: val_loss did not improve from 1.01360
# Epoch 364/1000
#  - 17s - loss: 0.0235 - val_loss: 1.2832
#
# Epoch 00364: val_loss did not improve from 1.01360
# Epoch 365/1000
#  - 17s - loss: 0.0214 - val_loss: 1.2841
#
# Epoch 00365: val_loss did not improve from 1.01360
# Epoch 366/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2840
#
# Epoch 00366: val_loss did not improve from 1.01360
# Epoch 367/1000
#  - 17s - loss: 0.0202 - val_loss: 1.2834
#
# Epoch 00367: val_loss did not improve from 1.01360
# Epoch 368/1000
#  - 17s - loss: 0.0200 - val_loss: 1.2793
#
# Epoch 00368: val_loss did not improve from 1.01360
# Epoch 369/1000
#  - 17s - loss: 0.0196 - val_loss: 1.2795
#
# Epoch 00369: val_loss did not improve from 1.01360
# Epoch 370/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2810
#
# Epoch 00370: val_loss did not improve from 1.01360
# Epoch 371/1000
#  - 17s - loss: 0.0194 - val_loss: 1.2849
#
# Epoch 00371: val_loss did not improve from 1.01360
# Epoch 372/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2813
#
# Epoch 00372: val_loss did not improve from 1.01360
# Epoch 373/1000
#  - 17s - loss: 0.0200 - val_loss: 1.2796
#
# Epoch 00373: val_loss did not improve from 1.01360
# Epoch 374/1000
#  - 17s - loss: 0.0201 - val_loss: 1.2865
#
# Epoch 00374: val_loss did not improve from 1.01360
# Epoch 375/1000
#  - 17s - loss: 0.0261 - val_loss: 1.3043
#
# Epoch 00375: val_loss did not improve from 1.01360
# Epoch 376/1000
#  - 17s - loss: 0.0476 - val_loss: 1.2969
#
# Epoch 00376: val_loss did not improve from 1.01360
# Epoch 377/1000
#  - 17s - loss: 0.0329 - val_loss: 1.2943
#
# Epoch 00377: val_loss did not improve from 1.01360
# Epoch 378/1000
#  - 17s - loss: 0.0242 - val_loss: 1.2876
#
# Epoch 00378: val_loss did not improve from 1.01360
# Epoch 379/1000
#  - 17s - loss: 0.0210 - val_loss: 1.2881
#
# Epoch 00379: val_loss did not improve from 1.01360
# Epoch 380/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2902
#
# Epoch 00380: val_loss did not improve from 1.01360
# Epoch 381/1000
#  - 17s - loss: 0.0190 - val_loss: 1.2909
#
# Epoch 00381: val_loss did not improve from 1.01360
# Epoch 382/1000
#  - 17s - loss: 0.0190 - val_loss: 1.2858
#
# Epoch 00382: val_loss did not improve from 1.01360
# Epoch 383/1000
#  - 17s - loss: 0.0191 - val_loss: 1.2927
#
# Epoch 00383: val_loss did not improve from 1.01360
# Epoch 384/1000
#  - 17s - loss: 0.0192 - val_loss: 1.2874
#
# Epoch 00384: val_loss did not improve from 1.01360
# Epoch 385/1000
#  - 17s - loss: 0.0194 - val_loss: 1.2881
#
# Epoch 00385: val_loss did not improve from 1.01360
# Epoch 386/1000
#  - 17s - loss: 0.0195 - val_loss: 1.2887
#
# Epoch 00386: val_loss did not improve from 1.01360
# Epoch 387/1000
#  - 17s - loss: 0.0197 - val_loss: 1.2867
#
# Epoch 00387: val_loss did not improve from 1.01360
# Epoch 388/1000
#  - 17s - loss: 0.0201 - val_loss: 1.2903
#
# Epoch 00388: val_loss did not improve from 1.01360
# Epoch 389/1000
#  - 17s - loss: 0.0242 - val_loss: 1.2958
#
# Epoch 00389: val_loss did not improve from 1.01360
# Epoch 390/1000
#  - 17s - loss: 0.0334 - val_loss: 1.3107
#
# Epoch 00390: val_loss did not improve from 1.01360
# Epoch 391/1000
#  - 17s - loss: 0.0325 - val_loss: 1.3139
#
# Epoch 00391: val_loss did not improve from 1.01360
# Epoch 392/1000
#  - 17s - loss: 0.0276 - val_loss: 1.3093
#
# Epoch 00392: val_loss did not improve from 1.01360
# Epoch 393/1000
#  - 17s - loss: 0.0233 - val_loss: 1.3047
#
# Epoch 00393: val_loss did not improve from 1.01360
# Epoch 394/1000
#  - 17s - loss: 0.0210 - val_loss: 1.3113
#
# Epoch 00394: val_loss did not improve from 1.01360
# Epoch 395/1000
#  - 17s - loss: 0.0197 - val_loss: 1.3087
#
# Epoch 00395: val_loss did not improve from 1.01360
# Epoch 396/1000
#  - 17s - loss: 0.0191 - val_loss: 1.3078
#
# Epoch 00396: val_loss did not improve from 1.01360
# Epoch 397/1000
# ...
# Epoch 853/1000
#  - 17s - loss: 0.0222 - val_loss: 1.3957
#
# Epoch 00853: val_loss did not improve from 1.01360
# Epoch 854/1000
#  - 17s - loss: 0.0351 - val_loss: 1.4047
#
# Epoch 00854: val_loss did not improve from 1.01360
# Epoch 855/1000
#  - 17s - loss: 0.0289 - val_loss: 1.3909
#
# Epoch 00855: val_loss did not improve from 1.01360
# Epoch 856/1000
#  - 17s - loss: 0.0223 - val_loss: 1.3949
#
# Epoch 00856: val_loss did not improve from 1.01360
# Epoch 857/1000
#  - 17s - loss: 0.0192 - val_loss: 1.3883
#
# Epoch 00857: val_loss did not improve from 1.01360
# Epoch 858/1000
#  - 17s - loss: 0.0181 - val_loss: 1.3836
#
# Epoch 00858: val_loss did not improve from 1.01360
# Epoch 859/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3820
#
# Epoch 00859: val_loss did not improve from 1.01360
# Epoch 860/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3849
#
# Epoch 00860: val_loss did not improve from 1.01360
# Epoch 861/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3856
#
# Epoch 00861: val_loss did not improve from 1.01360
# Epoch 862/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3830
#
# Epoch 00862: val_loss did not improve from 1.01360
# Epoch 863/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3882
#
# Epoch 00863: val_loss did not improve from 1.01360
# Epoch 864/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3841
#
# Epoch 00864: val_loss did not improve from 1.01360
# Epoch 865/1000
#  - 17s - loss: 0.0172 - val_loss: 1.3887
#
# Epoch 00865: val_loss did not improve from 1.01360
# Epoch 866/1000
#  - 17s - loss: 0.0174 - val_loss: 1.3900
#
# Epoch 00866: val_loss did not improve from 1.01360
# Epoch 867/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3889
#
# Epoch 00867: val_loss did not improve from 1.01360
# Epoch 868/1000
#  - 17s - loss: 0.0183 - val_loss: 1.3900
#
# Epoch 00868: val_loss did not improve from 1.01360
# Epoch 869/1000
#  - 17s - loss: 0.0312 - val_loss: 1.4213
#
# Epoch 00869: val_loss did not improve from 1.01360
# Epoch 870/1000
#  - 17s - loss: 0.0364 - val_loss: 1.4187
#
# Epoch 00870: val_loss did not improve from 1.01360
# Epoch 871/1000
#  - 17s - loss: 0.0259 - val_loss: 1.3999
#
# Epoch 00871: val_loss did not improve from 1.01360
# Epoch 872/1000
#  - 17s - loss: 0.0204 - val_loss: 1.3995
#
# Epoch 00872: val_loss did not improve from 1.01360
# Epoch 873/1000
#  - 17s - loss: 0.0186 - val_loss: 1.4042
#
# Epoch 00873: val_loss did not improve from 1.01360
# Epoch 874/1000
#  - 17s - loss: 0.0176 - val_loss: 1.4066
#
# Epoch 00874: val_loss did not improve from 1.01360
# Epoch 875/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3983
#
# Epoch 00875: val_loss did not improve from 1.01360
# Epoch 876/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4027
#
# Epoch 00876: val_loss did not improve from 1.01360
# Epoch 877/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4035
#
# Epoch 00877: val_loss did not improve from 1.01360
# Epoch 878/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4011
#
# Epoch 00878: val_loss did not improve from 1.01360
# Epoch 879/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4088
#
# Epoch 00879: val_loss did not improve from 1.01360
# Epoch 880/1000
#  - 17s - loss: 0.0172 - val_loss: 1.4069
#
# Epoch 00880: val_loss did not improve from 1.01360
# Epoch 881/1000
#  - 17s - loss: 0.0173 - val_loss: 1.4054
#
# Epoch 00881: val_loss did not improve from 1.01360
# Epoch 882/1000
#  - 17s - loss: 0.0173 - val_loss: 1.4044
#
# Epoch 00882: val_loss did not improve from 1.01360
# Epoch 883/1000
#  - 17s - loss: 0.0175 - val_loss: 1.4008
#
# Epoch 00883: val_loss did not improve from 1.01360
# Epoch 884/1000
#  - 17s - loss: 0.0176 - val_loss: 1.4052
#
# Epoch 00884: val_loss did not improve from 1.01360
# Epoch 885/1000
#  - 17s - loss: 0.0276 - val_loss: 1.4265
#
# Epoch 00885: val_loss did not improve from 1.01360
# Epoch 886/1000
#  - 17s - loss: 0.0377 - val_loss: 1.4242
#
# Epoch 00886: val_loss did not improve from 1.01360
# Epoch 887/1000
#  - 17s - loss: 0.0284 - val_loss: 1.4035
#
# Epoch 00887: val_loss did not improve from 1.01360
# Epoch 888/1000
#  - 17s - loss: 0.0220 - val_loss: 1.3997
#
# Epoch 00888: val_loss did not improve from 1.01360
# Epoch 889/1000
#  - 17s - loss: 0.0191 - val_loss: 1.3981
#
# Epoch 00889: val_loss did not improve from 1.01360
# Epoch 890/1000
#  - 17s - loss: 0.0177 - val_loss: 1.3997
#
# Epoch 00890: val_loss did not improve from 1.01360
# Epoch 891/1000
#  - 17s - loss: 0.0174 - val_loss: 1.3995
#
# Epoch 00891: val_loss did not improve from 1.01360
# Epoch 892/1000
#  - 17s - loss: 0.0169 - val_loss: 1.4016
#
# Epoch 00892: val_loss did not improve from 1.01360
# Epoch 893/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3962
#
# Epoch 00893: val_loss did not improve from 1.01360
# Epoch 894/1000
#  - 17s - loss: 0.0169 - val_loss: 1.3935
#
# Epoch 00894: val_loss did not improve from 1.01360
# Epoch 895/1000
#  - 17s - loss: 0.0171 - val_loss: 1.4022
#
# Epoch 00895: val_loss did not improve from 1.01360
# Epoch 896/1000
#  - 17s - loss: 0.0173 - val_loss: 1.4017
#
# Epoch 00896: val_loss did not improve from 1.01360
# Epoch 897/1000
#  - 17s - loss: 0.0172 - val_loss: 1.3924
#
# Epoch 00897: val_loss did not improve from 1.01360
# Epoch 898/1000
#  - 17s - loss: 0.0172 - val_loss: 1.3981
#
# Epoch 00898: val_loss did not improve from 1.01360
# Epoch 899/1000
#  - 17s - loss: 0.0175 - val_loss: 1.3933
#
# Epoch 00899: val_loss did not improve from 1.01360
# Epoch 900/1000
#  - 17s - loss: 0.0176 - val_loss: 1.3985
#
# Epoch 00900: val_loss did not improve from 1.01360
# Epoch 901/1000
#  - 17s - loss: 0.0216 - val_loss: 1.4179
#
# Epoch 00901: val_loss did not improve from 1.01360
# Epoch 902/1000
#  - 17s - loss: 0.0334 - val_loss: 1.4056
#
# Epoch 00902: val_loss did not improve from 1.01360
# Epoch 903/1000
#  - 17s - loss: 0.0332 - val_loss: 1.4037
#
# Epoch 00903: val_loss did not improve from 1.01360
# Epoch 904/1000
#  - 17s - loss: 0.0236 - val_loss: 1.3949
#
# Epoch 00904: val_loss did not improve from 1.01360
# Epoch 905/1000
#  - 17s - loss: 0.0196 - val_loss: 1.3874
#
# Epoch 00905: val_loss did not improve from 1.01360
# Epoch 906/1000
#  - 17s - loss: 0.0179 - val_loss: 1.3889
#
# Epoch 00906: val_loss did not improve from 1.01360
# Epoch 907/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3872
#
# Epoch 00907: val_loss did not improve from 1.01360
# Epoch 908/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3868
#
# Epoch 00908: val_loss did not improve from 1.01360
# Epoch 909/1000
#  - 17s - loss: 0.0168 - val_loss: 1.3878
#
# Epoch 00909: val_loss did not improve from 1.01360
# Epoch 910/1000
#  - 17s - loss: 0.0169 - val_loss: 1.3871
#
# Epoch 00910: val_loss did not improve from 1.01360
# Epoch 911/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3905
#
# Epoch 00911: val_loss did not improve from 1.01360
# Epoch 912/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3920
#
# Epoch 00912: val_loss did not improve from 1.01360
# Epoch 913/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3903
#
# Epoch 00913: val_loss did not improve from 1.01360
# Epoch 914/1000
#  - 17s - loss: 0.0172 - val_loss: 1.3911
#
# Epoch 00914: val_loss did not improve from 1.01360
# Epoch 915/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3948
#
# Epoch 00915: val_loss did not improve from 1.01360
# Epoch 916/1000
#  - 17s - loss: 0.0201 - val_loss: 1.4037
#
# Epoch 00916: val_loss did not improve from 1.01360
# Epoch 917/1000
#  - 17s - loss: 0.0306 - val_loss: 1.4079
#
# Epoch 00917: val_loss did not improve from 1.01360
# Epoch 918/1000
#  - 17s - loss: 0.0313 - val_loss: 1.4037
#
# Epoch 00918: val_loss did not improve from 1.01360
# Epoch 919/1000
#  - 17s - loss: 0.0244 - val_loss: 1.3950
#
# Epoch 00919: val_loss did not improve from 1.01360
# Epoch 920/1000
#  - 17s - loss: 0.0202 - val_loss: 1.3860
#
# Epoch 00920: val_loss did not improve from 1.01360
# Epoch 921/1000
#  - 17s - loss: 0.0183 - val_loss: 1.3934
#
# Epoch 00921: val_loss did not improve from 1.01360
# Epoch 922/1000
#  - 17s - loss: 0.0175 - val_loss: 1.3883
#
# Epoch 00922: val_loss did not improve from 1.01360
# Epoch 923/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3879
#
# Epoch 00923: val_loss did not improve from 1.01360
# Epoch 924/1000
#  - 17s - loss: 0.0169 - val_loss: 1.3856
#
# Epoch 00924: val_loss did not improve from 1.01360
# Epoch 925/1000
#  - 17s - loss: 0.0169 - val_loss: 1.3870
#
# Epoch 00925: val_loss did not improve from 1.01360
# Epoch 926/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3915
#
# Epoch 00926: val_loss did not improve from 1.01360
# Epoch 927/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3872
#
# Epoch 00927: val_loss did not improve from 1.01360
# Epoch 928/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3837
#
# Epoch 00928: val_loss did not improve from 1.01360
# Epoch 929/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3870
#
# Epoch 00929: val_loss did not improve from 1.01360
# Epoch 930/1000
#  - 17s - loss: 0.0174 - val_loss: 1.3885
#
# Epoch 00930: val_loss did not improve from 1.01360
# Epoch 931/1000
#  - 17s - loss: 0.0184 - val_loss: 1.3908
#
# Epoch 00931: val_loss did not improve from 1.01360
# Epoch 932/1000
#  - 17s - loss: 0.0308 - val_loss: 1.4123
#
# Epoch 00932: val_loss did not improve from 1.01360
# Epoch 933/1000
#  - 17s - loss: 0.0355 - val_loss: 1.3960
#
# Epoch 00933: val_loss did not improve from 1.01360
# Epoch 934/1000
#  - 17s - loss: 0.0263 - val_loss: 1.3881
#
# Epoch 00934: val_loss did not improve from 1.01360
# Epoch 935/1000
#  - 17s - loss: 0.0217 - val_loss: 1.3822
#
# Epoch 00935: val_loss did not improve from 1.01360
# Epoch 936/1000
#  - 17s - loss: 0.0184 - val_loss: 1.3822
#
# Epoch 00936: val_loss did not improve from 1.01360
# Epoch 937/1000
#  - 17s - loss: 0.0176 - val_loss: 1.3867
#
# Epoch 00937: val_loss did not improve from 1.01360
# Epoch 938/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3821
#
# Epoch 00938: val_loss did not improve from 1.01360
# Epoch 939/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3827
#
# Epoch 00939: val_loss did not improve from 1.01360
# Epoch 940/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3845
#
# Epoch 00940: val_loss did not improve from 1.01360
# Epoch 941/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3840
#
# Epoch 00941: val_loss did not improve from 1.01360
# Epoch 942/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3855
#
# Epoch 00942: val_loss did not improve from 1.01360
# Epoch 943/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3832
#
# Epoch 00943: val_loss did not improve from 1.01360
# Epoch 944/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3849
#
# Epoch 00944: val_loss did not improve from 1.01360
# Epoch 945/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3876
#
# Epoch 00945: val_loss did not improve from 1.01360
# Epoch 946/1000
#  - 17s - loss: 0.0173 - val_loss: 1.3866
#
# Epoch 00946: val_loss did not improve from 1.01360
# Epoch 947/1000
#  - 17s - loss: 0.0179 - val_loss: 1.3847
#
# Epoch 00947: val_loss did not improve from 1.01360
# Epoch 948/1000
#  - 17s - loss: 0.0211 - val_loss: 1.4063
#
# Epoch 00948: val_loss did not improve from 1.01360
# Epoch 949/1000
#  - 17s - loss: 0.0383 - val_loss: 1.4077
#
# Epoch 00949: val_loss did not improve from 1.01360
# Epoch 950/1000
#  - 17s - loss: 0.0311 - val_loss: 1.3897
#
# Epoch 00950: val_loss did not improve from 1.01360
# Epoch 951/1000
#  - 17s - loss: 0.0223 - val_loss: 1.3843
#
# Epoch 00951: val_loss did not improve from 1.01360
# Epoch 952/1000
#  - 17s - loss: 0.0196 - val_loss: 1.3854
#
# Epoch 00952: val_loss did not improve from 1.01360
# Epoch 953/1000
#  - 17s - loss: 0.0181 - val_loss: 1.3909
#
# Epoch 00953: val_loss did not improve from 1.01360
# Epoch 954/1000
#  - 17s - loss: 0.0174 - val_loss: 1.3877
#
# Epoch 00954: val_loss did not improve from 1.01360
# Epoch 955/1000
#  - 17s - loss: 0.0172 - val_loss: 1.3896
#
# Epoch 00955: val_loss did not improve from 1.01360
# Epoch 956/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3915
#
# Epoch 00956: val_loss did not improve from 1.01360
# Epoch 957/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3943
#
# Epoch 00957: val_loss did not improve from 1.01360
# Epoch 958/1000
#  - 17s - loss: 0.0170 - val_loss: 1.3901
#
# Epoch 00958: val_loss did not improve from 1.01360
# Epoch 959/1000
#  - 17s - loss: 0.0169 - val_loss: 1.3914
#
# Epoch 00959: val_loss did not improve from 1.01360
# Epoch 960/1000
#  - 17s - loss: 0.0171 - val_loss: 1.3989
#
# Epoch 00960: val_loss did not improve from 1.01360
# Epoch 961/1000
#  - 17s - loss: 0.0172 - val_loss: 1.3900
#
# Epoch 00961: val_loss did not improve from 1.01360
# Epoch 962/1000
#  - 17s - loss: 0.0172 - val_loss: 1.3972
#
# Epoch 00962: val_loss did not improve from 1.01360
# Epoch 963/1000
#  - 17s - loss: 0.0176 - val_loss: 1.3954
#
# Epoch 00963: val_loss did not improve from 1.01360
# Epoch 964/1000
#  - 17s - loss: 0.0183 - val_loss: 1.3981
#
# Epoch 00964: val_loss did not improve from 1.01360
# Epoch 965/1000
#  - 17s - loss: 0.0298 - val_loss: 1.4249
#
# Epoch 00965: val_loss did not improve from 1.01360
# Epoch 966/1000
#  - 17s - loss: 0.0347 - val_loss: 1.4153
#
# Epoch 00966: val_loss did not improve from 1.01360
# Epoch 967/1000
#  - 17s - loss: 0.0270 - val_loss: 1.4020
#
# Epoch 00967: val_loss did not improve from 1.01360
# Epoch 968/1000
#  - 17s - loss: 0.0225 - val_loss: 1.3963
#
# Epoch 00968: val_loss did not improve from 1.01360
# Epoch 969/1000
#  - 17s - loss: 0.0198 - val_loss: 1.4050
#
# Epoch 00969: val_loss did not improve from 1.01360
# Epoch 970/1000
#  - 17s - loss: 0.0185 - val_loss: 1.4037
#
# Epoch 00970: val_loss did not improve from 1.01360
# Epoch 971/1000
#  - 17s - loss: 0.0176 - val_loss: 1.4065
#
# Epoch 00971: val_loss did not improve from 1.01360
# Epoch 972/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4060
#
# Epoch 00972: val_loss did not improve from 1.01360
# Epoch 973/1000
#  - 17s - loss: 0.0169 - val_loss: 1.3992
#
# Epoch 00973: val_loss did not improve from 1.01360
# Epoch 974/1000
#  - 17s - loss: 0.0168 - val_loss: 1.4031
#
# Epoch 00974: val_loss did not improve from 1.01360
# Epoch 975/1000
#  - 17s - loss: 0.0167 - val_loss: 1.3996
#
# Epoch 00975: val_loss did not improve from 1.01360
# Epoch 976/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4023
#
# Epoch 00976: val_loss did not improve from 1.01360
# Epoch 977/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4013
#
# Epoch 00977: val_loss did not improve from 1.01360
# Epoch 978/1000
#  - 17s - loss: 0.0172 - val_loss: 1.4008
#
# Epoch 00978: val_loss did not improve from 1.01360
# Epoch 979/1000
#  - 17s - loss: 0.0172 - val_loss: 1.4019
#
# Epoch 00979: val_loss did not improve from 1.01360
# Epoch 980/1000
#  - 17s - loss: 0.0175 - val_loss: 1.3959
#
# Epoch 00980: val_loss did not improve from 1.01360
# Epoch 981/1000
#  - 17s - loss: 0.0180 - val_loss: 1.4062
#
# Epoch 00981: val_loss did not improve from 1.01360
# Epoch 982/1000
#  - 17s - loss: 0.0250 - val_loss: 1.4197
#
# Epoch 00982: val_loss did not improve from 1.01360
# Epoch 983/1000
#  - 17s - loss: 0.0361 - val_loss: 1.4199
#
# Epoch 00983: val_loss did not improve from 1.01360
# Epoch 984/1000
#  - 17s - loss: 0.0285 - val_loss: 1.4214
#
# Epoch 00984: val_loss did not improve from 1.01360
# Epoch 985/1000
#  - 17s - loss: 0.0228 - val_loss: 1.4112
#
# Epoch 00985: val_loss did not improve from 1.01360
# Epoch 986/1000
#  - 17s - loss: 0.0196 - val_loss: 1.4162
#
# Epoch 00986: val_loss did not improve from 1.01360
# Epoch 987/1000
#  - 17s - loss: 0.0184 - val_loss: 1.4157
#
# Epoch 00987: val_loss did not improve from 1.01360
# Epoch 988/1000
#  - 17s - loss: 0.0175 - val_loss: 1.4190
#
# Epoch 00988: val_loss did not improve from 1.01360
# Epoch 989/1000
#  - 17s - loss: 0.0172 - val_loss: 1.4129
#
# Epoch 00989: val_loss did not improve from 1.01360
# Epoch 990/1000
#  - 17s - loss: 0.0171 - val_loss: 1.4140
#
# Epoch 00990: val_loss did not improve from 1.01360
# Epoch 991/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4122
#
# Epoch 00991: val_loss did not improve from 1.01360
# Epoch 992/1000
#  - 17s - loss: 0.0169 - val_loss: 1.4090
#
# Epoch 00992: val_loss did not improve from 1.01360
# Epoch 993/1000
#  - 17s - loss: 0.0169 - val_loss: 1.4063
#
# Epoch 00993: val_loss did not improve from 1.01360
# Epoch 994/1000
#  - 17s - loss: 0.0170 - val_loss: 1.4108
#
# Epoch 00994: val_loss did not improve from 1.01360
# Epoch 995/1000
#  - 17s - loss: 0.0173 - val_loss: 1.4050
#
# Epoch 00995: val_loss did not improve from 1.01360
# Epoch 996/1000
#  - 17s - loss: 0.0172 - val_loss: 1.4069
#
# Epoch 00996: val_loss did not improve from 1.01360
# Epoch 997/1000
#  - 17s - loss: 0.0183 - val_loss: 1.4205
#
# Epoch 00997: val_loss did not improve from 1.01360
# Epoch 998/1000
#  - 17s - loss: 0.0236 - val_loss: 1.4217
#
# Epoch 00998: val_loss did not improve from 1.01360
# Epoch 999/1000
#  - 17s - loss: 0.0301 - val_loss: 1.4261
#
# Epoch 00999: val_loss did not improve from 1.01360
# Epoch 1000/1000
#  - 17s - loss: 0.0276 - val_loss: 1.4193
#
# Epoch 01000: val_loss did not improve from 1.01360

# %%
from pickle import load
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu


# load a clean dataset
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))


# fit a tokenizer
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer


# max sentence length
def max_length(lines):
    return max(len(line.split()) for line in lines)


# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X


# map an integer to a word
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None


# generate target given source sequence
def predict_sequence(model, tokenizer, source):
    prediction = model.predict(source, verbose=0)[0]
    integers = [argmax(vector) for vector in prediction]
    target = list()
    for i in integers:
        word = word_for_id(i, tokenizer)
        if word is None:
            break
        target.append(word)
    return ' '.join(target)


# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
    actual, predicted = list(), list()
    for i, source in enumerate(sources):
        # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_sequence(model, eng_tokenizer, source)
        raw_target, raw_src, test = raw_dataset[i]
        '''if i < 10:
            print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
        actual.append([raw_target.split()])
        predicted.append(translation.split())
    # calculate BLEU score
    print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
    print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
    print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
    print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))'''


# load datasets
dataset = load_clean_sentences('english-kannada-both36.pkl')
train = load_clean_sentences('english-kannada-train36.pkl')
test = load_clean_sentences('english-kannada-test36.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare kannada tokenizer
kan_tokenizer = create_tokenizer(dataset[:, 1])
kan_vocab_size = len(kan_tokenizer.word_index) + 1
kan_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(kan_tokenizer, kan_length, train[:, 1])
testX = encode_sequences(kan_tokenizer, kan_length, test[:, 1])


# load model
model = load_model('model32k.h5')
# test on some training sequences
#print('train')
#evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
#print('test')
#evaluate_model(model, eng_tokenizer, testX, test)

def custom_pred(sentence):
    data = [sentence]
    data = kan_tokenizer.texts_to_sequences(data)
    data = pad_sequences(data, maxlen=kan_length, padding='post')
    data = predict_sequence(model, eng_tokenizer, data)
    data = " ".join(data[:])
    return data
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-774db1fdc516> in <module>
#       1 from pickle import load
#       2 from numpy import argmax
# ----> 3 from keras.preprocessing.text import Tokenizer
#       4 from keras.preprocessing.sequence import pad_sequences
#       5 from keras.models import load_model
#
# ~/Mtkan/lib/python3.6/site-packages/keras/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/Mtkan/lib/python3.6/site-packages/keras/utils/__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7 from . import losses_utils
#       8 from . import metrics_utils
#
# ~/Mtkan/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# ~/Mtkan/lib/python3.6/site-packages/keras/backend/__init__.py in <module>
# ----> 1 from .load_backend import epsilon
#       2 from .load_backend import set_epsilon
#       3 from .load_backend import floatx
#       4 from .load_backend import set_floatx
#       5 from .load_backend import cast_to_floatx
#
# ~/Mtkan/lib/python3.6/site-packages/keras/backend/load_backend.py in <module>
#      88 elif _BACKEND == 'tensorflow':
#      89     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 90     from .tensorflow_backend import *
#      91 else:
#      92     # Try and load external backend.
#
# ~/Mtkan/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in <module>
#      54 get_graph = tf_keras_backend.get_graph
#      55 # learning_phase_scope = tf_keras_backend.learning_phase_scope  # TODO
# ---> 56 name_scope = tf.name_scope
#      57
#      58
#
# AttributeError: module 'tensorflow' has no attribute 'name_scope'

# %%
custom_pred("ಶ್ರೀನಿವಾಸ್ ಒಳ್ಳೆಯದು")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5aafa87881da> in <module>
# ----> 1 custom_pred("ಶ್ರೀನಿವಾಸ್ ಒಳ್ಳೆಯದು")
#
# <ipython-input-12-6fa1c108007d> in custom_pred(sentence)
#       1 def custom_pred(sentence):
#       2     data = [sentence]
# ----> 3     data = kan_tokenizer.texts_to_sequences(data)
#       4     data = pad_sequences(data, maxlen=kan_length, padding='post')
#       5     data = predict_sequence(model, eng_tokenizer, data)
#
# NameError: name 'kan_tokenizer' is not defined
